# %% [markdown]
# # Teori SVM

# %%
from luwiji.svm import illustration, demo

# %%
demo.problem(1)

# %%
illustration.choose_one

# %% [markdown]
# ### Solusi: Mencari margin paling lebar
# SVM ulunya dikenal sebagai maximum margin classifier. Ternyata alternatif untuk memperoleh macimum margin adalaha dengan mencari support vector(data yang diinginkan). itulah kenapa disebut support vector machine

# %% [markdown]
# ### C-Penalty Parameter

# %% [markdown]
# Semakin besar C => semakin besar penalty terhadap kesalahan => lebih sensitif
# semakin kecil C => semakin toleran thd kesalahan => lebih smooth

# %%
demo.C(1)
# Out:
# interactive(children=(FloatLogSlider(value=10.0, description='C', max=1.0, min=-2.0, step=0.25), Output()), _d…

# %% [markdown]
# ### Problem 2: Ternyata toleran saja tidak cukup

# %%
demo.problem(2)

# %%
demo.C(2)
# Out:
# interactive(children=(FloatLogSlider(value=10.0, description='C', max=1.0, min=-2.0, step=0.25), Output()), _d…

# %% [markdown]
# ### Solusi: kita butuh perspektif baru -> Kernel Kick
# Idenya adalah kita melakukan transformasi data2 kita ke dimensi lain. Misalkan kita transformasi menggunakan distribusi gaussian. Maka kita menyebutnya sebagai SVM menggunakan kernel Gaussian
#
# Kernel Gaussian merupakan salah satu dari keluarga RBF(Radial Basis Function)

# %%
demo.rbf()
# Out:
# interactive(children=(IntSlider(value=90, description='elevation', max=90, step=15), FloatSlider(value=0.0, de…

# %%
demo.kernel(2)
# Out:
# interactive(children=(ToggleButtons(description='Kernel', options=('linear', 'rbf'), value='linear'), FloatLog…

# %% [markdown]
# ### Problem 3: Scale

# %%
demo.problem(3)

# %% [markdown]
# ### Solusi: Big picture vs detail oriented -> gamma kernel coefficient

# %% [markdown]
# semakin besar gamma semakin detail

# %%
demo.gamma()
# Out:
# interactive(children=(FloatLogSlider(value=31.622776601683793, description='gamma', max=1.5, min=-1.5, step=0.…
