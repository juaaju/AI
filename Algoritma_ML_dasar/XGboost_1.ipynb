# %% [markdown]
# # Boosting

# %%
from luwiji.ensemble_learning import illustration

# %%
illustration.ensemble

# %% [markdown]
# Bagging itu akan membuat strong learner (bisa jadi overfit) -> Good learner

# %%
illustration.bagging

# %%
illustration.boosting

# %% [markdown]
# # Adaptive boosting
#
# Belajar dari kesalahan, belajar dari hal simppel. di training selanjutnya maka difokuskan hanya pada data yang salah prediksi

# %%
from luwiji.adaptive_boosting import illustration, demo

# %%
demo.adaboost()
# Out:
# interactive(children=(IntSlider(value=1, description='iteration', max=5, min=1), Output()), _dom_classes=('wid…

# %%
demo.adaboost_prediction()
# Out:
# interactive(children=(IntSlider(value=1, description='iteration', max=5, min=1), Output()), _dom_classes=('wid…

# %%
illustration.algoritma

# pembelajaran dilakukan berulang ulang dan akhirnya di agregat atau digabung

# %% [markdown]
# Parameter

# %%
demo.max_depth() # max depth tidak boleh terlalu besar, karena kita mau training yang simple
# Out:
# interactive(children=(IntSlider(value=1, description='iteration', max=10, min=1), IntSlider(value=1, descripti…

# %% [markdown]
# Learning Rate

# %%
demo.learning_rate()
# Out:
# interactive(children=(IntSlider(value=1, description='iteration', max=10, min=1), FloatSlider(value=1.0, descr…

# %%
demo.max_depth_and_lr()
# Out:
# interactive(children=(IntSlider(value=1, description='iteration', max=10, min=1), FloatSlider(value=1.0, descr…

# %% [markdown]
# # Gradien Boosting
#
# Analoginya seperti main golf. Error jadi dataset (memperkecil kesalahan)

# %%
from luwiji.gradient_boosting import illustration, demo

# %%
illustration.golf

# %%
demo.gradient_boosting()
# Out:
# interactive(children=(IntSlider(value=0, description='iterasi', max=9), Output()), _dom_classes=('widget-inter…

# %%
illustration.algoritma

# %% [markdown]
# Parameter

# %%
demo.max_depth()
# Out:
# interactive(children=(IntSlider(value=1, description='max_depth', max=3, min=1), IntSlider(value=0, descriptio…

# %%
demo.learning_rate()
# Out:
# interactive(children=(FloatSlider(value=1.0, description='lr', max=2.0, step=0.5), IntSlider(value=0, descript…

# %%
demo.max_depth_and_lr()
# Out:
# interactive(children=(FloatSlider(value=0.5, description='lr', max=0.5, min=0.1), IntSlider(value=1, descripti…
